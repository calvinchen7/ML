# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a dataframe with some data
df = pd.DataFrame({'data': np.random.randn(100)})

# Apply the log transformation to the 'data' column
df['log_data'] = np.log(df['data'])

# Print the dataframe
print(df)

df.plot()
# Out:
#         data  log_data
# 0   2.590592  0.951887
# 1  -0.024308       NaN
# 2   0.353957 -1.038579
# 3  -0.945325       NaN
# 4   1.384428  0.325287
# ..       ...       ...
# 95  0.250282 -1.385166
# 96 -0.014881       NaN
# 97 -0.885910       NaN
# 98 -0.276706       NaN
# 99  0.197059 -1.624250
#
# [100 rows x 2 columns]
# C:\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: >
